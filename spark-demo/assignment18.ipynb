# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

spark=SparkSession.builder.appName("SparkPartition").getOrCreate()
numFrame=spark.range(0,5000000).withColumn("value",col("id")%1000)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/14 05:34:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/06/14 05:34:28 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
print("Initial Number of partitions:",numFrame.rdd.getNumPartitions())
# Out:
# Initial Number of partitions: 2

# %%
#Increasing partitions to 12
newNumFrame=numFrame.repartition(12)
print("Current Number of partitions:",newNumFrame.rdd.getNumPartitions())
# Out:
# [Stage 0:>                                                          (0 + 2) / 2]
# Current Number of partitions: 12

# %%
#Reducing partitions to 3
finalNumFrame=newNumFrame.coalesce(3)
print("Final Number of partitions:",finalNumFrame.rdd.getNumPartitions())
# Out:
# [Stage 1:>                                                          (0 + 2) / 2]
# Final Number of partitions: 3
# [Stage 1:=============================>                             (1 + 1) / 2]
