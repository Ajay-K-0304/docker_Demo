# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col,sum,avg,desc

spark = SparkSession.builder.appName("SparkAppDemo").getOrCreate()
df = spark.read.option("header",True).option("inferSchema",True).csv("sales.csv")
df.show()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/14 16:35:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# +----------+------------+-----------+--------+
# |product_id|product_name|   category|   sales|
# +----------+------------+-----------+--------+
# |       101|      Laptop|Electronics|150000.0|
# |       102|      Mobile|Electronics| 95000.0|
# |       103|          TV|Electronics|120000.0|
# |       104|       Chair|  Furniture| 30000.0|
# |       105|       Table|  Furniture| 45000.0|
# |       106|        Sofa|  Furniture| 80000.0|
# |       107|  Headphones|Electronics| 25000.0|
# |       108|         Bed|  Furniture| 90000.0|
# +----------+------------+-----------+--------+
# 26/06/14 16:35:47 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
df.orderBy(col("sales").desc()).show()
# Out:
# +----------+------------+-----------+--------+
# |product_id|product_name|   category|   sales|
# +----------+------------+-----------+--------+
# |       101|      Laptop|Electronics|150000.0|
# |       103|          TV|Electronics|120000.0|
# |       102|      Mobile|Electronics| 95000.0|
# |       108|         Bed|  Furniture| 90000.0|
# |       106|        Sofa|  Furniture| 80000.0|
# |       105|       Table|  Furniture| 45000.0|
# |       104|       Chair|  Furniture| 30000.0|
# |       107|  Headphones|Electronics| 25000.0|
# +----------+------------+-----------+--------+

# %%
df.orderBy(col("sales").desc()).limit(3).show()
# Out:
# +----------+------------+-----------+--------+
# |product_id|product_name|   category|   sales|
# +----------+------------+-----------+--------+
# |       101|      Laptop|Electronics|150000.0|
# |       103|          TV|Electronics|120000.0|
# |       102|      Mobile|Electronics| 95000.0|
# +----------+------------+-----------+--------+

# %%
res=df.filter(col("sales") > 80000)
res.show()
res.write.csv("ans/salesData",header=True)
# Out:
# +----------+------------+-----------+--------+
# |product_id|product_name|   category|   sales|
# +----------+------------+-----------+--------+
# |       101|      Laptop|Electronics|150000.0|
# |       102|      Mobile|Electronics| 95000.0|
# |       103|          TV|Electronics|120000.0|
# |       108|         Bed|  Furniture| 90000.0|
# +----------+------------+-----------+--------+
